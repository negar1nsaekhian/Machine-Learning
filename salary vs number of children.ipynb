# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy as sci

from scipy.stats import linregress
from scipy.optimize import minimize

# %%
# Read the CSV file into a Pandas DataFrame
df = pd.read_csv('salary_and_number_of_childeren_data.csv')

x = df['Salary']/1000
y = df['Number of Children']
m = len(x)
m
# Out:
# 40

# %%
# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Create a scatter plot of the two columns
plt.scatter(x, y, label='Data Points')

# Create the regression line
regression_line = slope * x + intercept

# Plot the regression line
plt.plot(x, regression_line, color='red', label='Regression Line')

# Set labels and title
plt.xlabel('Salary (scaled by 1000)')
plt.ylabel('Number of Children')
plt.title('Scatter Plot with Linear Regression')

# Show legend
#plt.legend()

# Show the plot
plt.show()

# %%
import seaborn as sns

#create scatterplot with regression line and confidence interval lines
sns.regplot(x, y)
# Out:
# /Users/nasekhian/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Salary', ylabel='Number of Children'>

# %%
def linear_function(params, x):
    w, b = params
    x_np = np.array(df['Salary'])  # Convert x to a NumPy array
    return w * x_np + b

# Define the objective function to minimize (half of the sum of squared differences)
def objective_function(params):
    w, b   = params
    y_pred = linear_function(params, x)
    difference = y_pred - y
    k_value = (difference ** 2)
    return (1/(2*m)) * np.sum(k_value)

# Initial guess for parameters (w and b)
initial_params = [2.0, 1.0]
